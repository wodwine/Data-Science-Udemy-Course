# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("data/iris_dataset.csv")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
x = data.copy()

# %%
wcss=[]
for i in range(1,10):
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
number_clusters = range(1,10)
plt.plot(number_clusters,wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %%
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
data["Clusters"] = kmeans.predict(x)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Clusters
# 0             5.1          3.5           1.4          0.2         1
# 1             4.9          3.0           1.4          0.2         1
# 2             4.7          3.2           1.3          0.2         1
# 3             4.6          3.1           1.5          0.2         1
# 4             5.0          3.6           1.4          0.2         1
# ..            ...          ...           ...          ...       ...
# 145           6.7          3.0           5.2          2.3         0
# 146           6.3          2.5           5.0          1.9         0
# 147           6.5          3.0           5.2          2.0         0
# 148           6.2          3.4           5.4          2.3         0
# 149           5.9          3.0           5.1          1.8         0
#
# [150 rows x 5 columns]

# %%
plt.scatter(data["sepal_length"],data["sepal_width"],c=data["Clusters"],cmap="rainbow");

# %%
# Standardize
from sklearn import preprocessing

x_scaled = preprocessing.scale(x)
x_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
wcss=[]
for i in range(1,10):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
number_clusters = range(1,10)
plt.plot(number_clusters,wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %%
# 2 Clusters
kmeans_scaled = KMeans(2)
kmeans_scaled.fit(x_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
data["Clusters 2"] = kmeans_scaled.predict(x_scaled)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Clusters  \
# 0             5.1          3.5           1.4          0.2         1
# 1             4.9          3.0           1.4          0.2         1
# 2             4.7          3.2           1.3          0.2         1
# 3             4.6          3.1           1.5          0.2         1
# 4             5.0          3.6           1.4          0.2         1
# ..            ...          ...           ...          ...       ...
# 145           6.7          3.0           5.2          2.3         0
# 146           6.3          2.5           5.0          1.9         0
# 147           6.5          3.0           5.2          2.0         0
# 148           6.2          3.4           5.4          2.3         0
# 149           5.9          3.0           5.1          1.8         0
#
#      Clusters 2
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           0
# ...

# %%
plt.scatter(data["sepal_length"],data["sepal_width"],c=data["Clusters 2"],cmap="rainbow");

# %%
# 3 Clusters
kmeans_scaled = KMeans(3)
kmeans_scaled.fit(x_scaled)
data["Clusters 3"] = kmeans_scaled.predict(x_scaled)
plt.scatter(data["sepal_length"],data["sepal_width"],c=data["Clusters 3"],cmap="rainbow");

# %%
# 5 Clusters
kmeans_scaled = KMeans(5)
kmeans_scaled.fit(x_scaled)
data["Clusters 5"] = kmeans_scaled.predict(x_scaled)
plt.scatter(data["sepal_length"],data["sepal_width"],c=data["Clusters 5"],cmap="rainbow");

# %%
# Answer with 3 classes of species
real_data = pd.read_csv("data/iris_with_answers.csv")
real_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
real_data["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
real_data["species"] = real_data["species"].map({"setosa":0,"versicolor":1,"virginica":2})

# %%
# Sepal Real Data
plt.scatter(real_data["sepal_length"],real_data["sepal_width"],c=real_data["species"],cmap="rainbow");

# %%
# Sepal Predicted Data
plt.scatter(data["sepal_length"],data["sepal_width"],c=data["Clusters 3"],cmap="rainbow");

# %%
# Petal Real Data
plt.scatter(real_data['petal_length'], real_data['petal_width'], c= real_data ['species'], cmap = 'rainbow')

# %%
# Petal Predicted Data
plt.scatter(data["petal_length"],data["petal_width"],c=data["Clusters 3"],cmap="rainbow");
